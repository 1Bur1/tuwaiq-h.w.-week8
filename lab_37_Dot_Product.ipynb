# %% [markdown]
# <a href="https://colab.research.google.com/github/1Bur1/tuwaiq-h.w.-week8/blob/main/lab_37_Dot_Product.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Day 37 Activity: Dot Product
Tasks:
1) Compute dot product of two vectors
2) Compute cosine similarity
3) Interpret results
"""

import numpy as np

# Provided vectors (edit if you want different values)
a = np.array([1.0, 2.0, 3.0])
b = np.array([0.5, 1.0, 1.5])

# TODO: Compute dot and cosine similarity
dot_mul = np.dot(a,b)

def cosine_similarity(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

u = np.array([1,0])
v = np.array([ 0,1])
print(cosine_similarity(u,v))
# Out:
# 0.0
